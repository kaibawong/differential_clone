# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt  
import seaborn as sns

IMO = pd.read_table('IMO_effect.csv',delimiter =';')

#IMO.loc[:,['350 YLD','350 ASP', '350 ARO','350 PAR']].plot.bar(stacked=True,  figsize=(10,7))


IMO
# Out:
#                   Unnamed: 0                           Name    Location   DEN  \
# 0               AGBAMI201203                 AGBAMI 2012 03     Nigeria  0.79
# 1         ALGERIANCOND201011          ALGERIAN COND 2010 11     Algeria  0.70
# 2         ALVHEIMBLEND201309          ALVHEIM BLEND 2013 09         NWE  0.85
# 3         AASGARDBLEND201908          AASGARD BLEND 2019 08         NWE  0.79
# 4        AASTAHANSTEEN201904         AASTA HANSTEEN 2019 04         NWE  0.82
# 5             AZERIBTC201510              AZERI BTC 2015 10  Azerbaijan  0.84
# 6           AZERILIGHT201504            AZERI LIGHT 2015 04  Azerbaijan  0.85
# 7               BAKKEN201611                 BAKKEN 2016 11          US  0.81
# 8                 CLOV201609                   CLOV 2016 09      Angola  0.86
# 9                DALIA201305                  DALIA 2013 05      Angola  0.92
# 10             DRAUGEN200610                DRAUGEN 2006 10         NWE  0.82
# 11  EAGLEFORDCHEMGRADE201810  EAGLE FORD CHEM GRADE 2018 10          US  0.74
# 12   EAGLEFORDGENGRADE201709   EAGLE FORD GEN GRADE 2017 09          US  0.79
# 13             EKOFISK201506                EKOFISK 2015 06         NWE  0.83
# 14           FORTIESBL201111             FORTIES BL 2011 11         NWE  0.83
# 15            GINAKROG201902              GINA KROG 2019 02         NWE  0.83
# 16            GIRASSOL201502               GIRASSOL 2015 02      Angola  0.87
# 17         GOLIATBLEND201708           GOLIAT BLEND 2017 08         NWE  0.83
# 18          GRANEBLEND201903            GRANE BLEND 2019 03         NWE  0.88
# 19         GUDRUNBLEND201711           GUDRUN BLEND 2017 11         NWE  0.78
# 20            GULLFAKS201908               GULLFAKS 2019 08         NWE  0.83
# 21              HEBRON201807                 HEBRON 2018 07      Canada  0.93
# 22             HEIDRUN201801                HEIDRUN 2018 01         NWE  0.91
# 23       HIBERNIABLEND201606         HIBERNIA BLEND 2016 06      Canada  0.85
# 24          HUNGOBLEND201601            HUNGO BLEND 2016 01      Angola  0.88
# 25       JOHANSVERDRUP201305         JOHAN SVERDRUP 2013 05         NWE  0.89
# 26               JOTUN201701                  JOTUN 2017 01         NWE  0.82
# 27            KISSANJE201404               KISSANJE 2014 04      Angola  0.87
# 28        MARINERBLEND201609          MARINER BLEND 2016 09         NWE  0.96
# 29                MARS201709                   MARS 2017 09          US  0.88
# 30               MONDO201608                  MONDO 2016 08      Angola  0.89
# 31               NJORD200805                  NJORD 2008 05         NWE  0.79
# 32          NORNEBLEND201505            NORNE BLEND 2015 05         NWE  0.88
# 33          ORMENLANGE201801            ORMEN LANGE 2018 01         NWE  0.73
# 34             OSEBERG201604                OSEBERG 2016 04         NWE  0.83
# 35             PAZFLOR201502                PAZFLOR 2015 02      Angola  0.91
# 36           PEREGRINO201309              PEREGRINO 2013 09      Brazil  0.98
# 37            POSEIDON201709               POSEIDON 2017 09          US  0.88
# 38          RONCADOR20201408            RONCADOR 20 2014 08      Brazil  0.93
# 34    30.69     0.50     2.35    30.91    22.53     8.43     0.79     8.03
# 35    56.10     0.59     3.55    33.63    17.00    22.49     0.80     8.49
# 36    75.46     2.00    11.20    49.33    32.12    41.76     2.34    19.29
# 37    50.09     3.10     8.27    50.81    24.89    21.11     4.21    18.47
# 38    69.31     0.80     6.80    17.66    10.17    29.18     0.89    15.49
# 39    54.15     0.77     5.47    22.96    13.54    19.72     0.92    14.28
# 40    52.83     1.27     4.71    37.01    16.52    20.47     1.73    11.44
# 41    40.66     0.50     2.91    43.69    16.24    12.48     0.74     8.91
# 42    20.79     0.64     1.63    29.82    26.17     3.92     1.18     7.98
# 43     0.06     0.14     0.01    13.22    37.83     0.00     0.24     8.60
# 44    35.15     0.48     1.25    35.59    23.82     9.48     0.75     4.33
# 45    44.76     0.97     2.90    62.38    12.47    15.09     1.42     8.12
# 46    35.63     0.39     1.91    36.46    19.11     9.16     0.60     7.09
#
#     550 ARO  550 PAR
# 0     35.59    20.54
# 1     34.37    35.28
# 2     58.03    17.01
# 3     33.54    15.91
# 4     45.37    13.44
# 5     44.00    31.55
# 6     49.43    19.38
# 7     18.17    16.85
# 8     22.83    75.26
# 9     18.30    69.04
# 10    38.78     4.84
# 11    71.25    16.62
# 12    64.39    22.41
# 13    37.34    19.42
# 14    49.01    12.69
# 15    41.05    19.35
# 16    54.57    24.90
# 17    25.44    16.93
# 18    44.14    14.97
# 19    30.04    16.98
# 20    35.98    15.01
# 21    22.75     9.37
# 22    39.88    10.99
# 23    73.39     2.66
# 24    84.14     1.45
# 25    43.69    13.07
# 26    77.42    21.76
# 27    40.64     6.59
# 28    43.25    49.90
# 29    47.41    15.32
# 30    55.13    31.69
# 31    39.27    14.41
# 32    45.14     6.34
# 33    44.15    17.18
# 34    39.89    20.49
# 35    40.74    26.33
# 36    52.90    38.02
# 37    58.15    16.81
# 38    18.36     9.51
# 39    24.23    11.81
# 40    39.88    24.80
# 41    52.48    13.34
# 42    36.83    17.28
# 43    54.75     1.53
# 44    47.14    25.27
# 45    84.21     2.60
# 46    40.77    13.85

# %%
plt.rcParams['figure.dpi'] = 200



#ax = sns.scatterplot(x=IMO['350 PAR'], y=IMO['350 ARO'], hue= IMO["Name"], size=IMO["350 ASP"],data=IMO)
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

ax = sns.relplot(x='350 PAR', y='350 ARO', hue= 'Location', size='350 SUL',sizes=(0, 1000),alpha=.8, palette="muted",
                 data=IMO)
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

ax = sns.relplot(x='350 ARO', y='350 ASP', hue= 'Location', size='350 SUL',sizes=(0, 1000),alpha=.8, palette="muted",
                 data=IMO)

# %%
plt.rcParams['figure.dpi'] = 200





#ax = sns.scatterplot(x=IMO['350 PAR'], y=IMO['350 ARO'], hue= IMO["Name"], size=IMO["350 ASP"],data=IMO)
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

ax = sns.relplot(x='550 PAR', y='550 ARO', hue= 'Location', size='550 SUL',sizes=(0, 1000),alpha=.8, palette="muted",
                 data=IMO)
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

ax = sns.relplot(x='550 PAR', y='550 ASP', hue= 'Location', size='550 SUL',sizes=(0, 1000),alpha=.8, palette="muted",
                 data=IMO)
